# %%
Project 3
Analyzing and visualizing Movie ratings

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Student/Downloads/IMDB Top 250 Movies.csv")

# %%
# Displaying the dataset

# %%
data.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
data.tail()
# Out:
#      rank                name  year  rating                       genre  \
# 245   246            The Help  2011     8.1                       Drama
# 246   247         Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248             Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249              Gandhi  1982     8.0     Biography,Drama,History
# 249   250  Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 245       25000000      216639112
# ...

# %%
data.shape
# Out:
# (250, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
# Checking for missing values in the dataset

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# rank           0
# name           0
# year           0
# rating         0
# genre          0
# certificate    0
# run_time       0
# tagline        0
# budget         0
# box_office     0
# casts          0
# directors      0
# writers        0
# dtype: int64

# %%
df=data.drop(["rank","tagline","budget", "box_office","writers", "casts","run_time","directors"], axis=1)

# %%
df
# Out:
#                          name  year  rating                       genre  \
# 0    The Shawshank Redemption  1994     9.3                       Drama
# 1               The Godfather  1972     9.2                 Crime,Drama
# 2             The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       The Godfather Part II  1974     9.0                 Crime,Drama
# 4                12 Angry Men  1957     9.0                 Crime,Drama
# ..                        ...   ...     ...                         ...
# 245                  The Help  2011     8.1                       Drama
# 246               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248                    Gandhi  1982     8.0     Biography,Drama,History
# 249        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate
# 0             R
# 1             R
# 2         PG-13
# 3             R
# ...

# %%
# Checking for duplicates

# %%
def check_duplicates(df):
    return data.duplicated().any()

# %%
# Summary statistics for ratings

# %%
import numpy as np
mode_rating= df["rating"].mode()
mean_rating= df["rating"].mean()
median_rating= df["rating"].median()
print("mode",mode_rating, "mean", mean_rating,"and median is", median_rating)
# Out:
# mode 0    8.1
# Name: rating, dtype: float64 mean 8.3072 and median is 8.2

# %%
# Visualize distribution of ratings(boxplot and Histogram)

# %%
import seaborn as sns
sns.boxplot(y=df["rating"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['rating'], bins=20, kde=True)
plt.title('Movie Rating distribution')
plt.xlabel('Rating(1-10)')
plt.ylabel('frequency')
plt.show()

# %%
# Identifying the top rated movies and it's genres

# %%
df.columns
# Out:
# Index(['name', 'year', 'rating', 'genre', 'certificate'], dtype='object')

# %%
df_top=df.drop(["year","certificate"], axis=1)

# %%
df_top[df_top['rating']>8.307200]
# Out:
#                          name  rating                    genre
# 0    The Shawshank Redemption     9.3                    Drama
# 1               The Godfather     9.2              Crime,Drama
# 2             The Dark Knight     9.0       Action,Crime,Drama
# 3       The Godfather Part II     9.0              Crime,Drama
# 4                12 Angry Men     9.0              Crime,Drama
# ..                        ...     ...                      ...
# 86               High and Low     8.4      Crime,Drama,Mystery
# 87                  Capernaum     8.4                    Drama
# 92               Come and See     8.4       Drama,Thriller,War
# 107                  Hamilton     8.4  Biography,Drama,History
# 233                  Jai Bhim     8.8      Crime,Drama,Mystery
#
# [84 rows x 3 columns]

# %%
df_top.shape
# Out:
# (250, 3)

# %%
# There are 250 movies that have a high rating in this dataset

# %%
# Create  dashboards for the data

# %%
sns.barplot(x='rating',y=df_top.index, data=df_top, hue='genre',dodge=False, palette="Set2")
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.title("Rating By Title")
plt.show()
